# %%
#Qualified (if)

print('Welcome!')
gender = input("What is your gender? (M or F)")
age = int(input("How old are you? "))
exp_yrs = int(input("How many years of experiences do you have?"))
height = float(input("How tall are you? (in m)"))
weight = float(input("What is your weight? (in kg)"))

if (gender != 'F'):
    print("Sorry you're not qualified!")

if (gender == 'F'):

    if (age>=18 and age<=30):
        if(height>=1.55):
            if(weight<=45): print("Congratulation! You're qualified!")
            if(weight>45): print("Sorry you're not qualified!")
        if(height<1.55): print("Sorry you're not qualified!")

    if (age>30 and age<40):

        if(exp_yrs<2): print("Sorry you're not qualified!")

        if(exp_yrs>2 and exp_yrs<5):
            if(height>=1.6):
                if(weight>=50): print("Congratulation! You're qualified!")
                if(weight<50): print("Sorry you're not qualified!")
            if(height<1.6): print("Sorry you're not qualified!")
    
        if(exp_yrs>5):
            if(height>=1.55):
                if(weight<=45): print("Congratulation! You're qualified!")
                if(weight>45): print("Sorry you're not qualified!")
            if(height<1.55): print("Sorry you're not qualified!")

# %%
#Qualified (if - eles)

print('Welcome!')
gender = input("What is your gender? (M or F)")
age = int(input("How old are you? "))
exp_yrs = int(input("How many years of experiences do you have?"))
height = float(input("How tall are you? (in m)"))
weight = float(input("What is your weight? (in kg)"))

if (gender != 'F'):
    print("Sorry you're not qualified!")

else:
    if (gender == 'F'):

        if (age>=18 and age<=30):
            if(height>=1.55):
                if(weight<=45): print("Congratulation! You're qualified!")
                esle: print("Sorry you're not qualified!")
            else: print("Sorry you're not qualified!")

        else:
            if (age>30 and age<40):
                if(exp_yrs<2): print("Sorry you're not qualified!")
                
                else: 
                    if(exp_yrs>2 and exp_yrs<5):
                        if(height>=1.6):
                            if(weight>=50):
                                print("Congratulation! You're qualified!")
                            else: print("Sorry you're not qualified!")
                        else: print("Sorry you're not qualified!")
    
                    else: 
                        if(height>=1.55):
                            if(weight<=45): print("Congratulation! You're qualified!")
                            else: print("Sorry you're not qualified!")
                        else: print("Sorry you're not qualified!")

# %%
#Qualified (if - elif)

print('Welcome!')
gender = input("What is your gender? (M or F)")
age = int(input("How old are you? "))
exp_yrs = int(input("How many years of experiences do you have?"))
height = float(input("How tall are you? (in m)"))
weight = float(input("What is your weight? (in kg)"))

if  ( gender == 'F' and (age in range(18,31)) and weight <= 45 and height >= 1.55):
    print("Congratulation! You're qualified!")
elif (gender == 'F' and (age in range(30,40))):
    if ( (exp_yrs in range(2,5)) and height >=1.6 and weight >= 50):
        print("Congratulation! You're qualified!")
    if ( exp_yrs>=5 and height >=1.55 and weight <=45):
        print("Congratulation! You're qualified!")
else: print("Sorry you're not qualified!")
